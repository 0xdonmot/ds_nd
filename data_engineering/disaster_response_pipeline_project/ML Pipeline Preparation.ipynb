# %% [markdown]
# # ML Pipeline Preparation and Exploration
#
# ### 1. Import libraries and load data from database.

# %%
# import libraries
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine
import time

#load nltk libraries
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import pos_tag

#load sklearn text transformation libraries
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

#load sklearn ML libraries
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report, accuracy_score
from sklearn.base import BaseEstimator, TransformerMixin

# %%
# load data from database
engine = create_engine('sqlite:///DisasterMessages.db')
df = pd.read_sql('SELECT * FROM DisasterMessages',engine)
X = df['message'].values #sklearn requires algorithm to be in numpy array format
Y = df.iloc[:,4:].values #sklearn requires algorithm to be in numpy array format

# %%
# create small sample to optimise code
df_sample = df.sample(1000)
X_sample = df_sample['message'].values
Y_sample = df_sample.iloc[:,4:].values

# %%
df.head(1)
# Out:
#    id                                            message  \
# 0   2  Weather update - a cold front from Cuba that c...
#
#                                             original   genre  related  \
# 0  Un front froid se retrouve sur Cuba ce matin. ...  direct        1
#
#    request  offer  aid_related  medical_help  medical_products  ...  \
# 0        0      0            0             0                 0  ...
#
#    aid_centers  other_infrastructure  weather_related  floods  storm  fire  \
# 0            0                     0                0       0      0     0
#
#    earthquake  cold  other_weather  direct_report
# 0           0     0              0              0
#
# [1 rows x 40 columns]

# %% [markdown]
# ### 2. Define a tokenization function to process the text data

# %%
def tokenize(text):
    #remove punctuation
    pattern = '[^A-Za-z0-9]'
    text = re.sub(pattern, ' ', text)
    
    #convert to lowercase
    text = text.lower().strip()
    
    #tokenize
    words = word_tokenize(text)
    
    #remove stopwords (common words that don't add much meaning)
    stop_words = stopwords.words('english')
    words = [word for word in words if word not in stop_words]
    
    #lemmatize nouns (convert words to their roots)
    words = [WordNetLemmatizer().lemmatize(word, pos='n') for word in words]
    
    #lemmatize verbs
    words = [WordNetLemmatizer().lemmatize(word, pos='v') for word in words]
    
    #stem words (reduce words to their stem)
    words = [PorterStemmer().stem(word) for word in words]
    
    return words

# %% [markdown]
# ### 3. Build machine learning pipeline

# %%
#create pipeline
pipeline = Pipeline([
    ('vect',CountVectorizer(tokenizer = tokenize)),
    ('tfidf',TfidfTransformer()),
    ('clf',MultiOutputClassifier(RandomForestClassifier()))    
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_sample, Y_sample, test_size=0.33)

# fit pipeline
model = pipeline.fit(X_train,y_train)

# %% [markdown]
# ### 5. Test model

# %%
# predict test set
y_pred = model.predict(X_test)

# create function to iterate through columns and display classification report
def display_results(y_test,y_pred):
    
    number_of_columns = y_test.shape[1]
    for i in range(number_of_columns):
        print(df.columns[4+i].capitalize())
        print(classification_report(y_test[:,i],y_pred[:,i]))
        
display_results(y_test,y_pred)
# Out:
# Related
#               precision    recall  f1-score   support
#
#            0       0.64      0.09      0.16        74
#            1       0.77      0.98      0.87       251
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.77       330
#    macro avg       0.47      0.36      0.34       330
# weighted avg       0.73      0.77      0.70       330
#
# Request
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.95       283
#            1       0.89      0.36      0.52        47
#
#     accuracy                           0.90       330
#    macro avg       0.90      0.68      0.73       330
# weighted avg       0.90      0.90      0.88       330
#
# Offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Aid_related
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       191
#            1       0.77      0.53      0.62       139
#
#     accuracy                           0.73       330
#    macro avg       0.74      0.70      0.71       330
# weighted avg       0.74      0.73      0.72       330
#
# Medical_help
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       298
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.90       330
#    macro avg       0.45      0.50      0.47       330
# weighted avg       0.82      0.90      0.86       330
#
# Medical_products
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.97      0.95       330
#
# Search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       320
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.94      0.97      0.95       330
#
# Security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       323
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Military
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       318
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.96      0.95       330
#
# Child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Water
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       306
#            1       0.00      0.00      0.00        24
#
#     accuracy                           0.93       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.86      0.93      0.89       330
#
# Food
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       287
#            1       0.92      0.26      0.40        43
#
#     accuracy                           0.90       330
#    macro avg       0.91      0.63      0.67       330
# weighted avg       0.90      0.90      0.87       330
#
# Shelter
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       299
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.91       330
#    macro avg       0.45      0.50      0.48       330
# weighted avg       0.82      0.91      0.86       330
#
# Clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       322
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.98      0.96       330
#
# Missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.97      0.95       330
#
# Death
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       315
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.95       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.91      0.95      0.93       330
#
# Other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       288
#            1       0.00      0.00      0.00        42
#
#     accuracy                           0.87       330
#    macro avg       0.44      0.50      0.47       330
# weighted avg       0.76      0.87      0.81       330
#
# Infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       303
#            1       0.00      0.00      0.00        27
#
#     accuracy                           0.92       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.84      0.92      0.88       330
#
# Transport
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.97      0.95       330
#
# Buildings
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       309
#            1       0.00      0.00      0.00        21
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.88      0.94      0.91       330
#
# Electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       322
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.98      0.96       330
#
# Tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Aid_centers
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       325
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.97      0.98      0.98       330
#
# Other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       312
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.95       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.89      0.95      0.92       330
#
# Weather_related
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89       231
#            1       0.89      0.49      0.64        99
#
#     accuracy                           0.83       330
#    macro avg       0.85      0.73      0.76       330
# weighted avg       0.84      0.83      0.81       330
#
# Floods
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       306
#            1       0.00      0.00      0.00        24
#
#     accuracy                           0.93       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.86      0.93      0.89       330
#
# Storm
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       287
#            1       1.00      0.05      0.09        43
#
#     accuracy                           0.88       330
#    macro avg       0.94      0.52      0.51       330
# weighted avg       0.89      0.88      0.82       330
#
# Fire
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       325
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.97      0.98      0.98       330
#
# Earthquake
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       304
#            1       0.75      0.35      0.47        26
#
#     accuracy                           0.94       330
#    macro avg       0.85      0.67      0.72       330
# weighted avg       0.93      0.94      0.93       330
#
# Cold
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       316
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.92      0.96      0.94       330
#
# Other_weather
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       306
#            1       0.00      0.00      0.00        24
#
#     accuracy                           0.93       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.86      0.93      0.89       330
#
# Direct_report
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92       273
#            1       0.83      0.26      0.40        57
#
#     accuracy                           0.86       330
#    macro avg       0.85      0.63      0.66       330
# weighted avg       0.86      0.86      0.83       330
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 6. Improve your model - use grid search

# %%
# random forest grid search paramters
parameters = {
    'clf__estimator__criterion': ['gini','entropy'],
    'clf__estimator__max_features': ['sqrt','log2']
}

# %%
# initialise and fit grid search
cv = GridSearchCV(pipeline, param_grid=parameters)

model_gs = cv.fit(X_train,y_train)

# %%
# show best model parameters
model_gs.best_params_
# Out:
# {'clf__estimator__criterion': 'entropy',
#  'clf__estimator__max_features': 'log2'}

# %% [markdown]
# ### 7. Test model

# %%
# predict on test data and display results
y_pred_gs = cv.predict(X_test)

number_of_columns = y_test.shape[1]
for i in range(number_of_columns):
    print(df.columns[4+i].capitalize())
    print(classification_report(y_test[:,i],y_pred_gs[:,i]))
# Out:
# Related
#               precision    recall  f1-score   support
#
#            0       0.68      0.28      0.40        82
#            1       0.79      0.96      0.87       246
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.78       330
#    macro avg       0.49      0.41      0.42       330
# weighted avg       0.76      0.78      0.74       330
#
# Request
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       269
#            1       0.81      0.28      0.41        61
#
#     accuracy                           0.85       330
#    macro avg       0.83      0.63      0.67       330
# weighted avg       0.85      0.85      0.82       330
#
# Offer
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Aid_related
#               precision    recall  f1-score   support
#
#            0       0.65      0.93      0.77       190
#            1       0.77      0.34      0.47       140
#
#     accuracy                           0.68       330
#    macro avg       0.71      0.63      0.62       330
# weighted avg       0.70      0.68      0.64       330
#
# Medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       303
#            1       0.00      0.00      0.00        27
#
#     accuracy                           0.92       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.84      0.92      0.88       330
#
# Medical_products
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       311
#            1       0.00      0.00      0.00        19
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.89      0.94      0.91       330
#
# Search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.97      0.95       330
#
# Security
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       321
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.97       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.97      0.96       330
#
# Child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Water
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       300
#            1       0.00      0.00      0.00        30
#
#     accuracy                           0.91       330
#    macro avg       0.45      0.50      0.48       330
# weighted avg       0.83      0.91      0.87       330
#
# Food
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       287
#            1       1.00      0.02      0.05        43
#
#     accuracy                           0.87       330
#    macro avg       0.94      0.51      0.49       330
# weighted avg       0.89      0.87      0.82       330
#
# Shelter
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       302
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.92       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.84      0.92      0.87       330
#
# Clothing
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       325
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.97      0.98      0.98       330
#
# Money
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       320
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.94      0.97      0.95       330
#
# Missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Refugees
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       317
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.92      0.96      0.94       330
#
# Death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       317
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.92      0.96      0.94       330
#
# Other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       290
#            1       0.00      0.00      0.00        40
#
#     accuracy                           0.88       330
#    macro avg       0.44      0.50      0.47       330
# weighted avg       0.77      0.88      0.82       330
#
# Infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       301
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.91       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.83      0.91      0.87       330
#
# Transport
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       313
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.95       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.90      0.95      0.92       330
#
# Buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       316
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.92      0.96      0.94       330
#
# Electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       324
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.96      0.98      0.97       330
#
# Tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       307
#            1       0.00      0.00      0.00        23
#
#     accuracy                           0.93       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.87      0.93      0.90       330
#
# Weather_related
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89       252
#            1       0.88      0.27      0.41        78
#
#     accuracy                           0.82       330
#    macro avg       0.84      0.63      0.65       330
# weighted avg       0.83      0.82      0.78       330
#
# Floods
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       311
#            1       0.00      0.00      0.00        19
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.89      0.94      0.91       330
#
# Storm
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       313
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.95       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.90      0.95      0.92       330
#
# Fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Earthquake
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       297
#            1       0.92      0.36      0.52        33
#
#     accuracy                           0.93       330
#    macro avg       0.93      0.68      0.74       330
# weighted avg       0.93      0.93      0.92       330
#
# Cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       323
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       318
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.96      0.95       330
#
# Direct_report
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.91       270
#            1       0.78      0.12      0.20        60
#
#     accuracy                           0.83       330
#    macro avg       0.81      0.55      0.55       330
# weighted avg       0.82      0.83      0.78       330
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 8. Improve model

# %%
# define function to automate testing different classification models
def build_model(X, y, model, params = {}, test_size = 0.33):
    """
    This function takes in feature and target data, a classification algorithm to test and
    a dictionary of parameters for grid search to iterate through.
    It returns the average accuracy over the 36 categories.
    """
    start = time.time()
    
    pipeline = Pipeline([
        ('vect',CountVectorizer(tokenizer = tokenize)),
        ('tfidf',TfidfTransformer()),
        ('clf',MultiOutputClassifier(model()))    
    ])
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    cv = GridSearchCV(pipeline, param_grid=params)
    
    model = cv.fit(X_train,y_train)
    
    y_pred = model.predict(X_test)
    
    accuracy = 0
    for i in range(36):
        accuracy += accuracy_score(y_test[:,i],y_pred[:,i])
    
    avg_accuracy = accuracy/36
    
    display_results(y_test,y_pred)
    
    end = time.time()
    run_time = end-start
    print(f'time taken: {run_time}')
    
    return model, avg_accuracy, run_time

# %%
rf_test, rf_score, rf_run_time = build_model(X_sample,Y_sample, model = RandomForestClassifier, params = parameters)
# Out:
# Related
#               precision    recall  f1-score   support
#
#            0       0.62      0.15      0.24        67
#            1       0.81      0.98      0.89       261
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.80       330
#    macro avg       0.48      0.38      0.38       330
# weighted avg       0.77      0.80      0.75       330
#
# Request
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       271
#            1       0.79      0.39      0.52        59
#
#     accuracy                           0.87       330
#    macro avg       0.84      0.68      0.72       330
# weighted avg       0.86      0.87      0.85       330
#
# Offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Aid_related
#               precision    recall  f1-score   support
#
#            0       0.62      0.95      0.75       172
#            1       0.87      0.37      0.52       158
#
#     accuracy                           0.67       330
#    macro avg       0.74      0.66      0.64       330
# weighted avg       0.74      0.67      0.64       330
#
# Medical_help
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       299
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.91       330
#    macro avg       0.45      0.50      0.48       330
# weighted avg       0.82      0.91      0.86       330
#
# Medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       311
#            1       1.00      0.05      0.10        19
#
#     accuracy                           0.95       330
#    macro avg       0.97      0.53      0.54       330
# weighted avg       0.95      0.95      0.92       330
#
# Search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       318
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.96      0.95       330
#
# Security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       322
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.98      0.96       330
#
# Military
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       318
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.96      0.95       330
#
# Child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Water
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97       308
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.93       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.87      0.93      0.90       330
#
# Food
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       289
#            1       1.00      0.05      0.09        41
#
#     accuracy                           0.88       330
#    macro avg       0.94      0.52      0.51       330
# weighted avg       0.90      0.88      0.83       330
#
# Shelter
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       291
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.88       330
#    macro avg       0.44      0.50      0.47       330
# weighted avg       0.78      0.88      0.83       330
#
# Clothing
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       323
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Money
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.97       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.97      0.95       330
#
# Missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Refugees
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       318
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.96       330
#    macro avg       0.48      0.50      0.49       330
# weighted avg       0.93      0.96      0.95       330
#
# Death
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       309
#            1       0.00      0.00      0.00        21
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.88      0.94      0.91       330
#
# Other_aid
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       273
#            1       1.00      0.02      0.03        57
#
#     accuracy                           0.83       330
#    macro avg       0.91      0.51      0.47       330
# weighted avg       0.86      0.83      0.76       330
#
# Infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       306
#            1       0.00      0.00      0.00        24
#
#     accuracy                           0.93       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.86      0.93      0.89       330
#
# Transport
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       310
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.88      0.94      0.91       330
#
# Buildings
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       307
#            1       0.00      0.00      0.00        23
#
#     accuracy                           0.93       330
#    macro avg       0.47      0.50      0.48       330
# weighted avg       0.87      0.93      0.90       330
#
# Electricity
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       321
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.97       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.97      0.96       330
#
# Tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Hospitals
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       325
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.97      0.98      0.98       330
#
# Shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       313
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.95       330
#    macro avg       0.47      0.50      0.49       330
# weighted avg       0.90      0.95      0.92       330
#
# Weather_related
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       217
#            1       0.95      0.18      0.30       113
#
#     accuracy                           0.72       330
#    macro avg       0.83      0.59      0.56       330
# weighted avg       0.79      0.72      0.64       330
#
# Floods
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       298
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.90       330
#    macro avg       0.45      0.50      0.47       330
# weighted avg       0.82      0.90      0.86       330
#
# Storm
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       295
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.89       330
#    macro avg       0.45      0.50      0.47       330
# weighted avg       0.80      0.89      0.84       330
#
# Fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Earthquake
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       287
#            1       0.80      0.19      0.30        43
#
#     accuracy                           0.89       330
#    macro avg       0.85      0.59      0.62       330
# weighted avg       0.88      0.89      0.86       330
#
# Cold
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       321
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.97       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.97      0.96       330
#
# Other_weather
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       303
#            1       0.00      0.00      0.00        27
#
#     accuracy                           0.92       330
#    macro avg       0.46      0.50      0.48       330
# weighted avg       0.84      0.92      0.88       330
#
# Direct_report
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90       261
#            1       0.80      0.29      0.43        69
#
#     accuracy                           0.84       330
#    macro avg       0.82      0.64      0.67       330
# weighted avg       0.83      0.84      0.80       330
#
# time taken: 85.5978422164917
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# install and import xgboost
# !pip install xgboost
from xgboost import XGBClassifier
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /Users/miz/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.6.2)
# Requirement already satisfied: numpy in /Users/miz/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.20.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1

# %%
# test xgboost classifier
xgb_test, xgb_score, xgb_run_time = build_model(X_sample,Y_sample, model = XGBClassifier)
# Out:
# Related
#               precision    recall  f1-score   support
#
#            0       0.40      0.23      0.29        73
#            1       0.79      0.90      0.84       254
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.74       330
#    macro avg       0.40      0.38      0.38       330
# weighted avg       0.70      0.74      0.71       330
#
# Request
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       256
#            1       0.80      0.50      0.62        74
#
#     accuracy                           0.86       330
#    macro avg       0.84      0.73      0.77       330
# weighted avg       0.86      0.86      0.85       330
#
# Offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Aid_related
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       185
#            1       0.72      0.54      0.62       145
#
#     accuracy                           0.71       330
#    macro avg       0.71      0.69      0.69       330
# weighted avg       0.71      0.71      0.70       330
#
# Medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       302
#            1       0.14      0.04      0.06        28
#
#     accuracy                           0.90       330
#    macro avg       0.53      0.51      0.50       330
# weighted avg       0.85      0.90      0.87       330
#
# Medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       313
#            1       1.00      0.18      0.30        17
#
#     accuracy                           0.96       330
#    macro avg       0.98      0.59      0.64       330
# weighted avg       0.96      0.96      0.94       330
#
# Search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       320
#            1       0.40      0.20      0.27        10
#
#     accuracy                           0.97       330
#    macro avg       0.69      0.60      0.62       330
# weighted avg       0.96      0.97      0.96       330
#
# Security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       324
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Military
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       321
#            1       0.25      0.11      0.15         9
#
#     accuracy                           0.97       330
#    macro avg       0.61      0.55      0.57       330
# weighted avg       0.96      0.97      0.96       330
#
# Child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Water
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       311
#            1       0.78      0.37      0.50        19
#
#     accuracy                           0.96       330
#    macro avg       0.87      0.68      0.74       330
# weighted avg       0.95      0.96      0.95       330
#
# Food
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       290
#            1       0.85      0.57      0.69        40
#
#     accuracy                           0.94       330
#    macro avg       0.90      0.78      0.83       330
# weighted avg       0.93      0.94      0.93       330
#
# Shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       294
#            1       0.69      0.50      0.58        36
#
#     accuracy                           0.92       330
#    macro avg       0.82      0.74      0.77       330
# weighted avg       0.91      0.92      0.92       330
#
# Clothing
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       322
#            1       0.62      0.62      0.62         8
#
#     accuracy                           0.98       330
#    macro avg       0.81      0.81      0.81       330
# weighted avg       0.98      0.98      0.98       330
#
# Money
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       322
#            1       0.44      0.50      0.47         8
#
#     accuracy                           0.97       330
#    macro avg       0.72      0.74      0.73       330
# weighted avg       0.97      0.97      0.97       330
#
# Missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       326
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.99       330
#    macro avg       1.00      0.62      0.70       330
# weighted avg       0.99      0.99      0.99       330
#
# Refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       315
#            1       1.00      0.33      0.50        15
#
#     accuracy                           0.97       330
#    macro avg       0.98      0.67      0.74       330
# weighted avg       0.97      0.97      0.96       330
#
# Death
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       311
#            1       0.92      0.63      0.75        19
#
#     accuracy                           0.98       330
#    macro avg       0.95      0.81      0.87       330
# weighted avg       0.97      0.98      0.97       330
#
# Other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       281
#            1       0.44      0.24      0.32        49
#
#     accuracy                           0.84       330
#    macro avg       0.66      0.60      0.61       330
# weighted avg       0.81      0.84      0.82       330
#
# Infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       308
#            1       0.14      0.05      0.07        22
#
#     accuracy                           0.92       330
#    macro avg       0.54      0.51      0.51       330
# weighted avg       0.88      0.92      0.90       330
#
# Transport
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       308
#            1       0.33      0.05      0.08        22
#
#     accuracy                           0.93       330
#    macro avg       0.63      0.52      0.52       330
# weighted avg       0.90      0.93      0.90       330
#
# Buildings
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       311
#            1       0.71      0.26      0.38        19
#
#     accuracy                           0.95       330
#    macro avg       0.84      0.63      0.68       330
# weighted avg       0.94      0.95      0.94       330
#
# Electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       323
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Shops
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       313
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.94       330
#    macro avg       0.47      0.49      0.48       330
# weighted avg       0.90      0.94      0.92       330
#
# Weather_related
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87       234
#            1       0.71      0.52      0.60        96
#
#     accuracy                           0.80       330
#    macro avg       0.77      0.72      0.73       330
# weighted avg       0.79      0.80      0.79       330
#
# Floods
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       302
#            1       0.67      0.43      0.52        28
#
#     accuracy                           0.93       330
#    macro avg       0.81      0.70      0.74       330
# weighted avg       0.92      0.93      0.93       330
#
# Storm
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       297
#            1       0.59      0.30      0.40        33
#
#     accuracy                           0.91       330
#    macro avg       0.76      0.64      0.68       330
# weighted avg       0.89      0.91      0.90       330
#
# Fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       295
#            1       0.88      0.80      0.84        35
#
#     accuracy                           0.97       330
#    macro avg       0.93      0.89      0.91       330
# weighted avg       0.97      0.97      0.97       330
#
# Cold
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       318
#            1       0.50      0.08      0.14        12
#
#     accuracy                           0.96       330
#    macro avg       0.73      0.54      0.56       330
# weighted avg       0.95      0.96      0.95       330
#
# Other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       313
#            1       0.20      0.06      0.09        17
#
#     accuracy                           0.94       330
#    macro avg       0.58      0.52      0.53       330
# weighted avg       0.91      0.94      0.92       330
#
# Direct_report
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       261
#            1       0.65      0.51      0.57        69
#
#     accuracy                           0.84       330
#    macro avg       0.76      0.72      0.74       330
# weighted avg       0.83      0.84      0.83       330
#
# time taken: 14.674549102783203
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class FirstWordIsVerb(BaseEstimator, TransformerMixin):
    """
    Define custom transformer that returns True if a body of text starts with a verb
    else it returns false
    """
    def starting_verb(self,text):
        pos_tags = pos_tag(tokenize(text))
        first_word, first_tag = pos_tags[0]
        if first_tag in ['VB','VBP']:
            return True
        return False
    
    
    def fit(self, X, y = None):
        return self
    
    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %%
def build_model_2(X, y, model, params = {}, test_size = 0.33):
     """
    This function takes in feature and target data, a classification algorithm to test and
    a dictionary of parameters for grid search to iterate through.
    It returns the average accuracy over the 36 categories.
    It differs from the above function because it adds an extra feature - whether the first word
    is a verb.
    """
    start = time.time()
    pipeline = Pipeline([
        ('features', FeatureUnion([
                    ('text_pipeline',Pipeline([
                                        ('vect',CountVectorizer(tokenizer = tokenize)),
                                        ('tfidf',TfidfTransformer())    
                                            ])
                    ),
                     ('first_word_is_verb', FirstWordIsVerb())
                                        ])),
         ('clf',MultiOutputClassifier(model()))
    ])
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    cv = GridSearchCV(pipeline, param_grid=params)
    
    model = cv.fit(X_train,y_train)
    
    y_pred = model.predict(X_test)
    
    accuracy = 0
    for i in range(36):
        accuracy += accuracy_score(y_test[:,i],y_pred[:,i])
    
    avg_accuracy = accuracy/36
    
    display_results(y_test,y_pred)
    
    end = time.time()
    run_time = end-start
    print(f'time taken: {run_time}')
    
    return model, avg_accuracy, run_time

# %%
# train xgboost model on new pipeline
xgb_model_2, xgb_model_2_score, xgb_model_2_run_time = build_model_2(X_train,Y_train, model = XGBClassifier)
# Out:
# Related
#               precision    recall  f1-score   support
#
#            0       0.61      0.37      0.46        76
#            1       0.82      0.93      0.87       250
#            2       0.00      0.00      0.00         4
#
#     accuracy                           0.79       330
#    macro avg       0.48      0.43      0.44       330
# weighted avg       0.76      0.79      0.77       330
#
# Request
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       281
#            1       0.60      0.49      0.54        49
#
#     accuracy                           0.88       330
#    macro avg       0.76      0.72      0.73       330
# weighted avg       0.87      0.88      0.87       330
#
# Offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Aid_related
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77       205
#            1       0.63      0.64      0.63       125
#
#     accuracy                           0.72       330
#    macro avg       0.70      0.71      0.70       330
# weighted avg       0.72      0.72      0.72       330
#
# Medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       304
#            1       0.42      0.19      0.26        26
#
#     accuracy                           0.92       330
#    macro avg       0.68      0.58      0.61       330
# weighted avg       0.89      0.92      0.90       330
#
# Medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       317
#            1       0.33      0.08      0.12        13
#
#     accuracy                           0.96       330
#    macro avg       0.65      0.54      0.55       330
# weighted avg       0.94      0.96      0.94       330
#
# Search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       322
#            1       1.00      0.12      0.22         8
#
#     accuracy                           0.98       330
#    macro avg       0.99      0.56      0.61       330
# weighted avg       0.98      0.98      0.97       330
#
# Security
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       326
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.99       330
#    macro avg       0.49      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       321
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.97       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.95      0.97      0.96       330
#
# Child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       330
#
#     accuracy                           1.00       330
#    macro avg       1.00      1.00      1.00       330
# weighted avg       1.00      1.00      1.00       330
#
# Water
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       322
#            1       0.31      0.50      0.38         8
#
#     accuracy                           0.96       330
#    macro avg       0.65      0.74      0.68       330
# weighted avg       0.97      0.96      0.97       330
#
# Food
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       298
#            1       0.76      0.69      0.72        32
#
#     accuracy                           0.95       330
#    macro avg       0.86      0.83      0.85       330
# weighted avg       0.95      0.95      0.95       330
#
# Shelter
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       301
#            1       0.72      0.72      0.72        29
#
#     accuracy                           0.95       330
#    macro avg       0.85      0.85      0.85       330
# weighted avg       0.95      0.95      0.95       330
#
# Clothing
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       320
#            1       0.50      0.20      0.29        10
#
#     accuracy                           0.97       330
#    macro avg       0.74      0.60      0.64       330
# weighted avg       0.96      0.97      0.96       330
#
# Money
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       319
#            1       0.00      0.00      0.00        11
#
#     accuracy                           0.95       330
#    macro avg       0.48      0.49      0.49       330
# weighted avg       0.93      0.95      0.94       330
#
# Missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       328
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      0.99      0.99       330
#
# Refugees
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       325
#            1       0.33      0.20      0.25         5
#
#     accuracy                           0.98       330
#    macro avg       0.66      0.60      0.62       330
# weighted avg       0.98      0.98      0.98       330
#
# Death
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       315
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.97       330
#    macro avg       0.83      0.83      0.83       330
# weighted avg       0.97      0.97      0.97       330
#
# Other_aid
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       286
#            1       0.56      0.23      0.32        44
#
#     accuracy                           0.87       330
#    macro avg       0.72      0.60      0.63       330
# weighted avg       0.85      0.87      0.85       330
#
# Infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       316
#            1       0.25      0.07      0.11        14
#
#     accuracy                           0.95       330
#    macro avg       0.61      0.53      0.54       330
# weighted avg       0.93      0.95      0.94       330
#
# Transport
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       318
#            1       0.33      0.17      0.22        12
#
#     accuracy                           0.96       330
#    macro avg       0.65      0.58      0.60       330
# weighted avg       0.95      0.96      0.95       330
#
# Buildings
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       321
#            1       0.38      0.67      0.48         9
#
#     accuracy                           0.96       330
#    macro avg       0.68      0.82      0.73       330
# weighted avg       0.97      0.96      0.97       330
#
# Electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       323
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.98       330
#    macro avg       0.49      0.50      0.49       330
# weighted avg       0.96      0.98      0.97       330
#
# Tools
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.99       330
#
# Shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       327
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.99       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.98      0.99      0.98       330
#
# Other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       321
#            1       0.22      0.22      0.22         9
#
#     accuracy                           0.96       330
#    macro avg       0.60      0.60      0.60       330
# weighted avg       0.96      0.96      0.96       330
#
# Weather_related
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       243
#            1       0.73      0.56      0.64        87
#
#     accuracy                           0.83       330
#    macro avg       0.79      0.74      0.76       330
# weighted avg       0.82      0.83      0.82       330
#
# Floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       305
#            1       1.00      0.40      0.57        25
#
#     accuracy                           0.95       330
#    macro avg       0.98      0.70      0.77       330
# weighted avg       0.96      0.95      0.95       330
#
# Storm
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       297
#            1       0.70      0.42      0.53        33
#
#     accuracy                           0.92       330
#    macro avg       0.82      0.70      0.74       330
# weighted avg       0.91      0.92      0.92       330
#
# Fire
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       329
#            1       0.00      0.00      0.00         1
#
#     accuracy                           1.00       330
#    macro avg       0.50      0.50      0.50       330
# weighted avg       0.99      1.00      1.00       330
#
# Earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       302
#            1       0.76      0.79      0.77        28
#
#     accuracy                           0.96       330
#    macro avg       0.87      0.88      0.88       330
# weighted avg       0.96      0.96      0.96       330
#
# Cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       321
#            1       0.50      0.11      0.18         9
#
#     accuracy                           0.97       330
#    macro avg       0.74      0.55      0.58       330
# weighted avg       0.96      0.97      0.96       330
#
# Other_weather
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       311
#            1       0.25      0.05      0.09        19
#
#     accuracy                           0.94       330
#    macro avg       0.60      0.52      0.53       330
# weighted avg       0.90      0.94      0.92       330
#
# Direct_report
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       272
#            1       0.55      0.38      0.45        58
#
#     accuracy                           0.84       330
#    macro avg       0.71      0.66      0.68       330
# weighted avg       0.82      0.84      0.82       330
#
# time taken: 21.615350008010864
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
xgb_model_2_score, xgb_model_1_score
# Out:
# (0.9441077441077442, 0.9384680134680133)

# %% [markdown]
# #### Comment
# - New pipeline scores higher than old pipeline.

# %%
# use Randomized search to optimise xgboost parameters within the new pipeline
parameters = {'clf__estimator__learning_rate': [0.2, 0.3, 0.4],
              'clf__estimator__subsample': [0.8,0.9,1],
              'clf__estimator__min_child_weight': [1,2,3]
              }

pipeline = Pipeline([
        ('features', FeatureUnion([
                    ('text_pipeline',Pipeline([
                                        ('vect',CountVectorizer(tokenizer = tokenize)),
                                        ('tfidf',TfidfTransformer())    
                                            ])
                    ),
                     ('first_word_is_verb', FirstWordIsVerb())
                                        ])),
         ('clf',MultiOutputClassifier(XGBClassifier()))
    ])
    
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

cv = RandomizedSearchCV(pipeline, param_distributions=parameters)

model = cv.fit(X_train,y_train)

# %%
# define best model parameters
model.best_params_
# Out:
# {'clf__estimator__subsample': 1,
#  'clf__estimator__min_child_weight': 1,
#  'clf__estimator__learning_rate': 0.4}

# %%
# fit xgboost model according to best parameters
pipeline = Pipeline([
        ('features', FeatureUnion([
                    ('text_pipeline',Pipeline([
                                        ('vect',CountVectorizer(tokenizer = tokenize)),
                                        ('tfidf',TfidfTransformer())    
                                            ])
                    ),
                     ('first_word_is_verb', FirstWordIsVerb())
                                        ])),
         ('clf',MultiOutputClassifier(XGBClassifier(learning_rate=0.4, min_child_weight=1, subsample=1)))
    ])
    
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

model = pipeline.fit(X_train,y_train)

# %%
# test accuracy
y_pred = model.predict(X_test)

accuracy = 0
for i in range(36):
    accuracy += accuracy_score(y_test[:,i],y_pred[:,i])
    
avg_accuracy = accuracy/36

print(avg_accuracy)
# Out:
# 0.9505541429085116

# %% [markdown]
# #### Comment
# - Use the new pipeline, using an xgboost model and optimised parameters as final model.
